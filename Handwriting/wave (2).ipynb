# %%
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
import seaborn as sns
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Conv2D, MaxPool2D, Flatten, Dropout, Dense
from tensorflow.keras.optimizers import Adam

# %%
data_path = r'C:\Users\anagh\Downloads\DD'
wave_train_path = os.path.join(data_path, 'wave', 'wave', 'training')

# %%
def load_images_from_directory(directory, img_size=(128, 128)):
    images = []
    labels = []
    for label in os.listdir(directory):
        label_dir = os.path.join(directory, label)
        if os.path.isdir(label_dir):
            for file in os.listdir(label_dir):
                file_path = os.path.join(label_dir, file)
                if file_path.endswith('.png') or file_path.endswith('.jpg'):
                    image = cv2.imread(file_path)
                    image = cv2.resize(image, img_size)  # Resize image to img_size
                    images.append(image)
                    labels.append(label)
    return np.array(images), np.array(labels)

# %%
x_train, y_train = load_images_from_directory(wave_train_path)

print(f"x_train shape: {x_train.shape}")
print(f"y_train shape: {y_train.shape}")
# Out:
# x_train shape: (72, 128, 128, 3)
# y_train shape: (72,)

# %%
# Splitting the data into train and test sets
x_train, x_test, y_train, y_test = train_test_split(x_train, y_train, test_size=0.2, stratify=y_train, random_state=42)

# %%
# Data Distribution
unique_train, count_train = np.unique(y_train, return_counts=True)
plt.figure(figsize=(20, 10))
sns.barplot(x=unique_train, y=count_train).set_title("Number of training images per category:")
plt.show()

# %%
unique_test, count_test = np.unique(y_test, return_counts=True)
plt.figure(figsize=(20, 10))
sns.barplot(x=unique_test, y=count_test).set_title("Number of testing images per category:")
plt.show()

# %%
# Augmenting the Dataset
train_data_generator = ImageDataGenerator(rotation_range=360, horizontal_flip=True, vertical_flip=True)

x_aug_train = []
y_aug_train = []

for (i, v) in enumerate(y_train):
    x_img = x_train[i]
    x_img = np.expand_dims(x_img, axis=0)
    aug_iter = train_data_generator.flow(x_img, batch_size=1, shuffle=True)
    for j in range(70):
        aug_image = next(aug_iter)[0].astype('uint8')
        x_aug_train.append(aug_image)
        y_aug_train.append(v)

x_train = np.concatenate((x_train, np.array(x_aug_train)), axis=0)
y_train = np.concatenate((y_train, np.array(y_aug_train)), axis=0)

print(f"x_train shape after augmentation: {x_train.shape}")
print(f"y_train shape after augmentation: {y_train.shape}")
# Out:
# x_train shape after augmentation: (4047, 128, 128, 3)
# y_train shape after augmentation: (4047,)

# %%
# Preprocessing the Images
x_train = np.array([cv2.cvtColor(cv2.resize(img, (128, 128)), cv2.COLOR_BGR2GRAY) for img in x_train])
x_test = np.array([cv2.cvtColor(cv2.resize(img, (128, 128)), cv2.COLOR_BGR2GRAY) for img in x_test])

x_train = x_train / 255.0
x_test = x_test / 255.0

label_encoder = LabelEncoder()
y_train = to_categorical(label_encoder.fit_transform(y_train))
y_test = to_categorical(label_encoder.transform(y_test))

x_train = np.expand_dims(x_train, axis=-1)
x_test = np.expand_dims(x_test, axis=-1)

print(f"x_train shape after preprocessing: {x_train.shape}")
print(f"y_train shape after preprocessing: {y_train.shape}")
print(f"x_test shape after preprocessing: {x_test.shape}")
print(f"y_test shape after preprocessing: {y_test.shape}")
# Out:
# x_train shape after preprocessing: (4047, 128, 128, 1)
# y_train shape after preprocessing: (4047, 2)
# x_test shape after preprocessing: (15, 128, 128, 1)
# y_test shape after preprocessing: (15, 2)

# %%
# Define the Model
def parkinson_disease_detection_model(input_shape=(128, 128, 1)):
    regularizer = tf.keras.regularizers.l2(0.001)
    model = Sequential()
    model.add(Input(shape=input_shape))
    model.add(Conv2D(128, (5, 5), padding='same', strides=(1, 1), name='conv1', activation='relu', kernel_initializer='glorot_uniform', kernel_regularizer=regularizer))
    model.add(MaxPool2D((9, 9), strides=(3, 3)))
    model.add(Conv2D(64, (5, 5), padding='same', strides=(1, 1), name='conv2', activation='relu', kernel_initializer='glorot_uniform', kernel_regularizer=regularizer))
    model.add(MaxPool2D((7, 7), strides=(3, 3)))
    model.add(Conv2D(32, (3, 3), padding='same', strides=(1, 1), name='conv3', activation='relu', kernel_initializer='glorot_uniform', kernel_regularizer=regularizer))
    model.add(MaxPool2D((5, 5), strides=(2, 2)))
    model.add(Conv2D(32, (3, 3), padding='same', strides=(1, 1), name='conv4', activation='relu', kernel_initializer='glorot_uniform', kernel_regularizer=regularizer))
    model.add(MaxPool2D((3, 3), strides=(2, 2)))
    model.add(Flatten())
    model.add(Dropout(0.5))
    model.add(Dense(64, activation='relu', kernel_initializer='glorot_uniform', name='fc1'))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation='softmax', kernel_initializer='glorot_uniform', name='fc3'))
    optimizer = Adam(3.15e-5)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

model = parkinson_disease_detection_model(input_shape=(128, 128, 1))
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv1 (Conv2D)                       │ (None, 128, 128, 128)       │           3,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 40, 40, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2 (Conv2D)                       │ (None, 40, 40, 64)          │         204,864 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 12, 12, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv3 (Conv2D)                       │ (None, 12, 12, 32)          │          18,464 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 4, 4, 32)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv4 (Conv2D)                       │ (None, 4, 4, 32)            │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 1, 1, 32)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ fc1 (Dense)                          │ (None, 64)                  │           2,112 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ fc3 (Dense)                          │ (None, 2)                   │             130 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 238,146 (930.26 KB)
#  Trainable params: 238,146 (930.26 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Training the Model
hist = model.fit(x_train, y_train, batch_size=128, epochs=70, validation_data=(x_test, y_test))
# Out:
# Epoch 1/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 132s 4s/step - accuracy: 0.4829 - loss: 0.8565 - val_accuracy: 0.5333 - val_loss: 0.8489
# Epoch 2/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 119s 4s/step - accuracy: 0.5079 - loss: 0.8475 - val_accuracy: 0.4667 - val_loss: 0.8430
# Epoch 3/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 123s 4s/step - accuracy: 0.5037 - loss: 0.8416 - val_accuracy: 0.4667 - val_loss: 0.8374
# Epoch 4/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 114s 4s/step - accuracy: 0.5079 - loss: 0.8352 - val_accuracy: 0.4000 - val_loss: 0.8317
# Epoch 5/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 109s 3s/step - accuracy: 0.4994 - loss: 0.8307 - val_accuracy: 0.5333 - val_loss: 0.8261
# Epoch 6/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 119s 4s/step - accuracy: 0.4942 - loss: 0.8251 - val_accuracy: 0.4667 - val_loss: 0.8214
# Epoch 7/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 128s 4s/step - accuracy: 0.5195 - loss: 0.8196 - val_accuracy: 0.4667 - val_loss: 0.8171
# Epoch 8/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 124s 4s/step - accuracy: 0.5040 - loss: 0.8152 - val_accuracy: 0.4667 - val_loss: 0.8124
# Epoch 9/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 120s 4s/step - accuracy: 0.5115 - loss: 0.8106 - val_accuracy: 0.4667 - val_loss: 0.8082
# Epoch 10/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 120s 4s/step - accuracy: 0.5256 - loss: 0.8062 - val_accuracy: 0.4667 - val_loss: 0.8038
# Epoch 11/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 122s 4s/step - accuracy: 0.5267 - loss: 0.8018 - val_accuracy: 0.4667 - val_loss: 0.8000
# Epoch 12/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 120s 4s/step - accuracy: 0.5188 - loss: 0.7981 - val_accuracy: 0.4667 - val_loss: 0.7965
# Epoch 13/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 122s 4s/step - accuracy: 0.5201 - loss: 0.7949 - val_accuracy: 0.4667 - val_loss: 0.7919
# Epoch 14/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 124s 4s/step - accuracy: 0.5172 - loss: 0.7912 - val_accuracy: 0.4667 - val_loss: 0.7890
# Epoch 15/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 107s 3s/step - accuracy: 0.5404 - loss: 0.7867 - val_accuracy: 0.4667 - val_loss: 0.7844
# Epoch 16/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 118s 4s/step - accuracy: 0.5384 - loss: 0.7834 - val_accuracy: 0.5333 - val_loss: 0.7816
# Epoch 17/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 124s 4s/step - accuracy: 0.5315 - loss: 0.7803 - val_accuracy: 0.4667 - val_loss: 0.7799
# Epoch 18/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 136s 4s/step - accuracy: 0.5535 - loss: 0.7759 - val_accuracy: 0.4667 - val_loss: 0.7788
# Epoch 19/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 124s 4s/step - accuracy: 0.5528 - loss: 0.7739 - val_accuracy: 0.5333 - val_loss: 0.7702
# Epoch 20/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 124s 4s/step - accuracy: 0.5634 - loss: 0.7702 - val_accuracy: 0.5333 - val_loss: 0.7673
# Epoch 21/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 126s 4s/step - accuracy: 0.5523 - loss: 0.7677 - val_accuracy: 0.6667 - val_loss: 0.7609
# Epoch 22/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 134s 4s/step - accuracy: 0.5457 - loss: 0.7655 - val_accuracy: 0.5333 - val_loss: 0.7596
# Epoch 23/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 124s 4s/step - accuracy: 0.5622 - loss: 0.7619 - val_accuracy: 0.5333 - val_loss: 0.7649
# Epoch 24/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 122s 4s/step - accuracy: 0.5830 - loss: 0.7553 - val_accuracy: 0.6667 - val_loss: 0.7495
# Epoch 25/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 118s 4s/step - accuracy: 0.5699 - loss: 0.7529 - val_accuracy: 0.6667 - val_loss: 0.7438
# Epoch 26/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 115s 4s/step - accuracy: 0.5959 - loss: 0.7488 - val_accuracy: 0.5333 - val_loss: 0.7619
# Epoch 27/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 113s 4s/step - accuracy: 0.5698 - loss: 0.7492 - val_accuracy: 0.4667 - val_loss: 0.7542
# Epoch 28/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 119s 4s/step - accuracy: 0.5961 - loss: 0.7415 - val_accuracy: 0.6667 - val_loss: 0.7338
# Epoch 29/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 157s 4s/step - accuracy: 0.5775 - loss: 0.7434 - val_accuracy: 0.5333 - val_loss: 0.7539
# Epoch 30/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 128s 4s/step - accuracy: 0.5801 - loss: 0.7399 - val_accuracy: 0.4667 - val_loss: 0.7496
# Epoch 31/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 111s 3s/step - accuracy: 0.5707 - loss: 0.7435 - val_accuracy: 0.4667 - val_loss: 0.7520
# Epoch 32/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 30s 925ms/step - accuracy: 0.5934 - loss: 0.7352 - val_accuracy: 0.5333 - val_loss: 0.7389
# Epoch 33/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 30s 936ms/step - accuracy: 0.5822 - loss: 0.7343 - val_accuracy: 0.4667 - val_loss: 0.7426
# Epoch 34/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 31s 962ms/step - accuracy: 0.6040 - loss: 0.7259 - val_accuracy: 0.4667 - val_loss: 0.7466
# Epoch 35/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 32s 984ms/step - accuracy: 0.6140 - loss: 0.7273 - val_accuracy: 0.4667 - val_loss: 0.7414
# Epoch 36/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 31s 978ms/step - accuracy: 0.5978 - loss: 0.7256 - val_accuracy: 0.5333 - val_loss: 0.7274
# Epoch 37/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 32s 987ms/step - accuracy: 0.6265 - loss: 0.7161 - val_accuracy: 0.5333 - val_loss: 0.7246
# Epoch 38/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 31s 981ms/step - accuracy: 0.6184 - loss: 0.7165 - val_accuracy: 0.5333 - val_loss: 0.7285
# Epoch 39/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 32s 985ms/step - accuracy: 0.6213 - loss: 0.7152 - val_accuracy: 0.5333 - val_loss: 0.7065
# Epoch 40/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 32s 991ms/step - accuracy: 0.6158 - loss: 0.7167 - val_accuracy: 0.6000 - val_loss: 0.7103
# Epoch 41/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 32s 1000ms/step - accuracy: 0.6174 - loss: 0.7143 - val_accuracy: 0.5333 - val_loss: 0.7227
# Epoch 42/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 31s 978ms/step - accuracy: 0.6240 - loss: 0.7146 - val_accuracy: 0.5333 - val_loss: 0.7365
# Epoch 43/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 31s 972ms/step - accuracy: 0.6082 - loss: 0.7182 - val_accuracy: 0.5333 - val_loss: 0.7377
# Epoch 44/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 31s 980ms/step - accuracy: 0.6505 - loss: 0.7058 - val_accuracy: 0.5333 - val_loss: 0.7378
# Epoch 45/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 31s 976ms/step - accuracy: 0.6362 - loss: 0.7113 - val_accuracy: 0.5333 - val_loss: 0.7316
# Epoch 46/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 31s 980ms/step - accuracy: 0.6464 - loss: 0.7056 - val_accuracy: 0.5333 - val_loss: 0.7341
# Epoch 47/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 32s 985ms/step - accuracy: 0.6431 - loss: 0.7124 - val_accuracy: 0.5333 - val_loss: 0.7314
# Epoch 48/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 32s 992ms/step - accuracy: 0.6577 - loss: 0.6981 - val_accuracy: 0.4667 - val_loss: 0.7542
# Epoch 49/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 31s 973ms/step - accuracy: 0.6441 - loss: 0.6973 - val_accuracy: 0.5333 - val_loss: 0.7248
# Epoch 50/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 31s 977ms/step - accuracy: 0.6555 - loss: 0.6962 - val_accuracy: 0.6000 - val_loss: 0.7078
# Epoch 51/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 31s 969ms/step - accuracy: 0.6694 - loss: 0.6840 - val_accuracy: 0.6000 - val_loss: 0.7043
# Epoch 52/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 31s 975ms/step - accuracy: 0.6614 - loss: 0.6957 - val_accuracy: 0.6000 - val_loss: 0.6831
# Epoch 53/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 31s 977ms/step - accuracy: 0.6488 - loss: 0.6944 - val_accuracy: 0.5333 - val_loss: 0.7167
# Epoch 54/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.6801 - loss: 0.6817 - val_accuracy: 0.5333 - val_loss: 0.6993
# Epoch 55/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 31s 946ms/step - accuracy: 0.6678 - loss: 0.6883 - val_accuracy: 0.6000 - val_loss: 0.7091
# Epoch 56/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 30s 927ms/step - accuracy: 0.6701 - loss: 0.6916 - val_accuracy: 0.5333 - val_loss: 0.7188
# Epoch 57/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 29s 915ms/step - accuracy: 0.6690 - loss: 0.6897 - val_accuracy: 0.5333 - val_loss: 0.6925
# Epoch 58/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 30s 920ms/step - accuracy: 0.6693 - loss: 0.6899 - val_accuracy: 0.6000 - val_loss: 0.7090
# Epoch 59/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 30s 928ms/step - accuracy: 0.6854 - loss: 0.6834 - val_accuracy: 0.5333 - val_loss: 0.7158
# Epoch 60/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 30s 927ms/step - accuracy: 0.6889 - loss: 0.6780 - val_accuracy: 0.4667 - val_loss: 0.7452
# Epoch 61/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 30s 924ms/step - accuracy: 0.6630 - loss: 0.6859 - val_accuracy: 0.5333 - val_loss: 0.6974
# Epoch 62/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 31s 960ms/step - accuracy: 0.6871 - loss: 0.6755 - val_accuracy: 0.5333 - val_loss: 0.7139
# Epoch 63/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.6908 - loss: 0.6683 - val_accuracy: 0.5333 - val_loss: 0.7212
# Epoch 64/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.6791 - loss: 0.6786 - val_accuracy: 0.6000 - val_loss: 0.7099
# Epoch 65/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 32s 985ms/step - accuracy: 0.6960 - loss: 0.6736 - val_accuracy: 0.6000 - val_loss: 0.7117
# Epoch 66/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 31s 982ms/step - accuracy: 0.6993 - loss: 0.6695 - val_accuracy: 0.5333 - val_loss: 0.7337
# Epoch 67/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 31s 972ms/step - accuracy: 0.7017 - loss: 0.6720 - val_accuracy: 0.7333 - val_loss: 0.6605
# Epoch 68/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 32s 987ms/step - accuracy: 0.6906 - loss: 0.6702 - val_accuracy: 0.6000 - val_loss: 0.7038
# Epoch 69/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 31s 981ms/step - accuracy: 0.7039 - loss: 0.6586 - val_accuracy: 0.6000 - val_loss: 0.7126
# Epoch 70/70
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 32s 987ms/step - accuracy: 0.6795 - loss: 0.6730 - val_accuracy: 0.6000 - val_loss: 0.7125

# %%
figure = plt.figure(figsize=(10, 10))
plt.plot(hist.history['accuracy'], label='Train_accuracy')
plt.plot(hist.history['val_accuracy'], label='Test_accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc="upper left")
plt.show()

figure2 = plt.figure(figsize=(10, 10))
plt.plot(hist.history['loss'], label='Train_loss')
plt.plot(hist.history['val_loss'], label='Test_loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc="upper left")
plt.show()

# %%
import pandas as pd
from sklearn.metrics import confusion_matrix, classification_report

# %%
ypred = model.predict(x_test)
ypred = np.argmax(ypred, axis=1)
y_test_pred = np.argmax(y_test, axis=1)
print(classification_report(y_test_pred, ypred))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
#               precision    recall  f1-score   support
#
#            0       0.75      0.38      0.50         8
#            1       0.55      0.86      0.67         7
#
#     accuracy                           0.60        15
#    macro avg       0.65      0.62      0.58        15
# weighted avg       0.65      0.60      0.58        15

# %%
matrix = confusion_matrix(y_test_pred, ypred)
df_cm = pd.DataFrame(matrix, index=[0, 1], columns=[0, 1])
figure = plt.figure(figsize=(5, 5))
sns.heatmap(df_cm, annot=True, fmt='d')
# Out:
# <Axes: >

# %%
model.save('wavem.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
labels = ['Healthy', 'Parkinson']
image_healthy = cv2.imread(r'C:\Users\anagh\Downloads\DD\wave\wave\testing\healthy\V08HO01.png')
image_parkinson = cv2.imread(r"C:\Users\anagh\Downloads\DD\wave\wave\testing\parkinson\V14PO03.png")

image_healthy = cv2.resize(image_healthy, (128, 128))
image_healthy = cv2.cvtColor(image_healthy, cv2.COLOR_BGR2GRAY)
image_healthy = np.array(image_healthy)
image_healthy = np.expand_dims(image_healthy, axis=0)
image_healthy = np.expand_dims(image_healthy, axis=-1)

image_parkinson = cv2.resize(image_parkinson, (128, 128))
image_parkinson = cv2.cvtColor(image_parkinson, cv2.COLOR_BGR2GRAY)
image_parkinson = np.array(image_parkinson)
image_parkinson = np.expand_dims(image_parkinson, axis=0)
image_parkinson = np.expand_dims(image_parkinson, axis=-1)

# %%
ypred_healthy = model.predict(image_healthy)
ypred_parkinson = model.predict(image_parkinson)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step

# %%
figure = plt.figure(figsize=(2, 2))
img_healthy = np.squeeze(image_healthy, axis=0)
plt.imshow(img_healthy)
plt.axis('off')
plt.title(f'Prediction by the model: {labels[np.argmax(ypred_healthy[0], axis=0)]}')
plt.show()

# %%
figure = plt.figure(figsize=(2, 2))
image_parkinson = np.squeeze(image_parkinson, axis=0)
plt.imshow(image_parkinson)
plt.axis('off')
plt.title(f'Prediction by the model: {labels[np.argmax(ypred_parkinson[0], axis=0)]}')
plt.show()
